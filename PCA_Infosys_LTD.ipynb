# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Infosys.csv')
df = pd.DataFrame(data)
df
# Out:
#      co_code  nse_opening_price  nse_high_price  nse_low_price  \
# 0     100632             737.25          742.30         729.75
# 1     100632             737.35          765.45         735.40
# 2     100632             755.00          764.00         752.50
# 3     100632             765.20          775.00         761.50
# 4     100632             769.40          796.95         765.55
# ..       ...                ...             ...            ...
# 124   100632            1249.90         1249.90        1226.00
# 125   100632            1238.45         1248.00        1236.00
# 126   100632            1235.00         1254.45        1235.00
# 127   100632            1253.00         1253.30        1238.15
# 128   100632            1243.00         1258.40        1239.00
#
#      nse_traded_qty  nse_avg_rate  nse_delivery_qty  \
# 0           5477687        736.05           2540508
# 1          17263764        756.33           7512460
# 2           7796573        759.35           3290825
# 3           8811009        768.11           4031067
# 4          19362666        785.79           8292880
# ..              ...           ...               ...
# 124         7313885       1236.34           2637421
# 125         4607051       1240.58           2098658
# 126         6878105       1246.33           3219736
# 127         5194690       1247.48           2378603
# 128         7430470       1249.41           3974062
#
#      equity_facevalue_on_stkdate
# 0                              5
# 1                              5
# 2                              5
# 3                              5
# 4                              5
# ..                           ...
# 124                            5
# 125                            5
# 126                            5
# 127                            5
# 128                            5
#
# [129 rows x 8 columns]

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
scalar.fit(data)
scaled_data = scalar.transform(data)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca.fit(scaled_data)
data_pca = pca.transform(scaled_data)
print(data_pca)
data_pca.shape
# Out:
# [[ 4.83775539 -0.96162992]
#  [ 4.54370793  1.33465163]
#  [ 4.47243385 -0.58195934]
#  [ 4.29634089 -0.30215598]
#  [ 4.02213364  1.70121829]
#  [ 4.08674121 -0.33664968]
#  [ 4.08664246 -0.77568247]
#  [ 4.14411739 -1.28297229]
#  [ 3.87337083 -0.3172954 ]
#  [ 3.88106511 -0.50457871]
#  [ 3.45852942  2.06330235]
#  [ 1.70169723  9.80166505]
#  [ 2.0246949   1.8288129 ]
#  [ 1.74502329  0.97049642]
#  [ 1.43856775  0.13618355]
#  [ 1.60321401  0.8569689 ]
#  [ 1.88813892  0.75416278]
#  [ 1.89391868  0.86375047]
#  [ 1.53886616  0.77507073]
#  [ 1.23256948  0.56782005]
#  [ 1.24535997 -0.11642204]
#  [ 1.00280891  0.43087451]
#  [ 0.98458105 -0.31257293]
#  [ 1.16695805 -0.39215697]
#  [ 1.1756897   0.08928504]
#  [ 1.2864674  -0.26974899]
#  [ 1.1439126  -0.08108667]
#  [ 1.12718664 -0.70411789]
#  [ 1.29656406 -1.03848767]
#  [ 1.27028673 -0.98008689]
#  [ 1.31828371 -0.93931487]
#  [ 1.21122131 -1.271312  ]
#  [ 1.20737343 -1.28142053]
#  [ 1.1345676  -0.68630688]
#  [ 1.07551367 -0.93933336]
#  [ 1.04523931 -0.86045069]
#  [ 1.18443787 -1.15243871]
#  [ 1.17676127 -0.58045392]
#  [ 1.36591371 -0.90844254]
#  [ 1.42214695 -0.83651751]
#  [ 1.40402292 -1.15179107]
#  [ 1.23674782 -0.98160053]
#  [ 1.35906095 -0.30567504]
#  [ 1.50118298  0.70236833]
#  [ 1.71749632 -0.58187617]
#  [ 1.8268177  -1.05535665]
#  [ 1.5591494  -0.5584396 ]
#  [ 1.77006378 -0.32541616]
#  [ 1.79279989 -0.79052038]
#  [ 1.4824731   0.1391612 ]
#  [ 1.56011669 -1.08751359]
#  [ 1.58567043 -1.20053174]
#  [ 1.45611203 -0.94530457]
#  [ 0.92497743  1.70665569]
#  [ 0.74753968  0.02804197]
#  [ 0.60433149 -0.28324048]
#  [ 0.30995149  1.00405745]
#  [ 0.23232879  0.90772517]
#  [ 0.21268284  0.52779469]
#  [ 0.32631903  0.08878691]
#  [ 0.08978196  0.10147847]
#  [ 0.54460314  0.71391653]
#  [ 0.59508643  0.22616855]
#  [ 0.32851674 -0.55857551]
#  [ 0.21470916 -0.770848  ]
#  [ 0.25413249 -0.50638229]
#  [ 0.17012638 -1.00950693]
#  [-0.15147945  0.77910704]
#  [-0.33093971 -0.35589714]
#  [-0.39471701 -0.31525299]
#  [-1.26923724  1.40942501]
#  [-1.17765576 -0.27434076]
#  [-1.64105842  0.56254689]
#  [-2.006074    0.97776628]
#  [-2.05988363  0.77914009]
#  [-1.94463266  3.24577459]
#  [-1.44407743  0.39092571]
#  [-1.72965813  0.73836827]
#  [-1.66563436 -0.06700106]
#  [-2.13066575  3.04262369]
#  [-1.88876857  0.11424317]
#  [-1.68086558 -0.20372808]
#  [-1.46117069 -0.97627968]
#  [-1.14129896 -0.01822142]
#  [-0.9953506  -0.73870629]
#  [-0.68425337 -0.94973821]
#  [-0.64589436 -0.66616198]
#  [-0.61825063 -0.6943274 ]
#  [-0.66756079 -0.70920443]
#  [-0.99657399  0.53195538]
#  [-1.37356824 -0.19423983]
#  [-1.28965018 -0.39651244]
#  [-1.72562262 -0.3267608 ]
#  [-1.25440809  1.07044127]
#  [-1.29133185  0.2718751 ]
#  [-1.63290736 -0.45345878]
#  [-1.55070695 -1.05299995]
#  [-1.6985298  -2.18510951]
#  [-1.77737395  0.79675754]
#  [-1.54563177  0.23452354]
#  [-1.26646925  0.03874139]
#  [-1.22531738 -0.51996957]
#  [-1.54035411 -0.0657807 ]
#  [-1.8857207  -0.84971719]
#  [-1.69438793 -0.17122308]
#  [-1.40870307  0.19852914]
#  [-1.65244049  4.96160719]
#  [-1.52569811 -0.37550629]
#  [-1.71121587 -0.99913502]
#  [-1.92834318  1.89218594]
#  [-1.66144369  0.15020164]
#  [-1.93387365 -0.50469941]
#  [-2.10619407  0.3902633 ]
#  [-2.34931295 -0.06102344]
#  [-2.22969893 -0.01311547]
#  [-2.29547429  0.49296322]
#  [-2.21588494 -0.76945309]
#  [-2.13215761 -0.70716046]
#  [-2.20157558 -0.51667131]
#  [-2.23559136 -0.74927288]
#  [-2.66547588  1.02585288]
#  [-2.59356254 -0.37861355]
#  [-2.76817176 -0.26192558]
#  [-3.60684976  0.8232963 ]
#  [-3.47933797 -1.01715074]
#  [-3.47809521 -1.38031738]
#  [-3.53171367 -0.89186166]
#  [-3.60208068 -1.26001943]
#  [-3.62702698 -0.64280163]]
# (129, 2)

# %%
plt.figure(figsize =(8, 6))
plt.scatter(data_pca[:, 0], data_pca[:, 1], cmap ='plasma')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
pca.components_
# Out:
# array([[ 0.        , -0.4985433 , -0.49899345, -0.49877358,  0.02366   ,
#         -0.49921685, -0.06251221,  0.        ],
#        [ 0.        , -0.01858969,  0.0094193 , -0.03250095,  0.7096688 ,
#         -0.01281929,  0.70335997,  0.        ]])
