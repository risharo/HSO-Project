# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Axis Bank.csv')
df = pd.DataFrame(data)
df
# Out:
#      co_code  nse_opening_price  nse_high_price  nse_low_price  \
# 0     256066             410.00          437.35         406.65
# 1     256066             441.00          441.50         421.30
# 2     256066             430.00          431.60         423.65
# 3     256066             434.15          437.60         431.10
# 4     256066             433.50          449.00         426.20
# ..       ...                ...             ...            ...
# 124   256066             595.00          614.00         594.15
# 125   256066             614.00          620.80         614.00
# 126   256066             620.70          632.40         618.60
# 127   256066             632.25          634.00         618.20
# 128   256066             622.40          625.95         616.00
#
#      nse_traded_qty  nse_avg_rate  nse_delivery_qty  \
# 0          53380997        423.30          11277321
# 1          50362840        427.80           8019429
# 2          31044470        427.75           5973108
# 3          18425359        434.51           3120874
# 4          37991906        438.58           6686878
# ..              ...           ...               ...
# 124        15488083        608.39           3419704
# 125         8444506        618.16           2177035
# 126        13765454        627.14           3717138
# 127        10262221        624.41           2239876
# 128        12306502        620.51           3900705
#
#      equity_facevalue_on_stkdate
# 0                              2
# 1                              2
# 2                              2
# 3                              2
# 4                              2
# ..                           ...
# 124                            2
# 125                            2
# 126                            2
# 127                            2
# 128                            2
#
# [129 rows x 8 columns]

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
scalar.fit(data)
scaled_data = scalar.transform(data)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)
pca.fit(scaled_data)
data_pca = pca.transform(scaled_data)
print(data_pca)
data_pca.shape
# Out:
# [[-2.39005447  2.68699495]
#  [-2.02191281  1.77051702]
#  [-1.96591799  0.09054499]
#  [-1.69777944 -1.33792784]
#  [-1.80184349  0.70415623]
#  [-1.51454417  1.16211456]
#  [-1.33216908  0.24368721]
#  [-1.455061   -0.30826543]
#  [-1.5595698  -1.09196574]
#  [-1.9405096  -0.15323217]
#  [-1.97879255  1.5998598 ]
#  [-1.97111645 -0.37434785]
#  [-1.85558304  0.73926366]
#  [-1.74509387  0.02597896]
#  [-1.63652438  2.02731605]
#  [-1.2471743   6.57540394]
#  [-0.95617389  1.72091299]
#  [-1.36613237  0.12401581]
#  [-1.56151356 -0.47049867]
#  [-1.85530198  0.45792548]
#  [-1.60918357 -0.83932092]
#  [-1.69540224 -0.15691792]
#  [-1.93686911 -0.4159432 ]
#  [-1.98052967 -0.50302387]
#  [-2.04703117 -0.81501788]
#  [-1.71451578  0.54220132]
#  [-1.82369078  0.91986699]
#  [-1.72251403 -1.51914079]
#  [-1.681891   -1.49280601]
#  [-1.60053253  0.52542519]
#  [-1.41592046 -0.58952394]
#  [-1.23289316 -0.15993311]
#  [-1.57895237  2.86924207]
#  [-1.73760804  1.38587505]
#  [-1.531124   -0.41761915]
#  [-1.33163384 -0.75408557]
#  [-1.58077944 -0.92931841]
#  [-1.54610814  0.67978412]
#  [-1.37690046 -0.72223342]
#  [-1.28125887 -0.03474594]
#  [-1.14413141  0.19026117]
#  [-0.7583556  -0.27465919]
#  [-0.50248602  3.17503383]
#  [ 0.13630579  4.32846062]
#  [-0.27289824  0.59589556]
#  [-0.44286027 -0.91864304]
#  [-0.35070987 -1.36362295]
#  [-0.9528075   0.88178917]
#  [-1.11990605 -0.66411236]
#  [-1.18369882 -0.9691077 ]
#  [-1.75358836  1.17034786]
#  [-1.69295664  0.75317711]
#  [-1.41930741 -1.43066191]
#  [-1.31925793 -1.35551521]
#  [-1.46050752 -1.58047319]
#  [-1.38716835 -0.97656657]
#  [-1.44879385 -1.67575842]
#  [-1.45018863 -0.49002046]
#  [-1.68951148 -1.24394257]
#  [-2.1916479  -0.08186264]
#  [-2.21211819 -1.42765445]
#  [-2.37648749 -0.54602108]
#  [-2.41081917 -0.96913662]
#  [-1.87771108 -1.00679753]
#  [-1.68613107 -1.14263463]
#  [-1.9750464  -1.40398139]
#  [-1.68407297 -0.97623591]
#  [-1.40640092 -0.57244007]
#  [-1.31677738 -0.67753147]
#  [-1.29253349 -0.90184329]
#  [-1.1314364  -0.36914312]
#  [-1.10855131  0.08161191]
#  [-0.72901473 -1.0925394 ]
#  [-0.8157072  -1.47692074]
#  [-0.90059571 -1.58381844]
#  [-0.74639188  0.50200803]
#  [-0.76553006 -1.52046294]
#  [-0.40824224  0.35108704]
#  [-0.19169496 -0.41575339]
#  [-0.054976    0.21306621]
#  [ 0.07415789  1.11100555]
#  [ 0.3700376  -0.49361599]
#  [ 0.14855758 -0.7746416 ]
#  [-0.06227981 -0.41215237]
#  [ 0.14440635  0.07009526]
#  [-0.11832063  2.34317571]
#  [-0.18041917 -0.89884882]
#  [ 0.18091911  1.91400012]
#  [ 0.82384428  0.52155358]
#  [ 0.61166279  0.48186465]
#  [ 1.00585535  0.53808446]
#  [ 1.09602288 -0.19871697]
#  [ 1.52931327  0.46373767]
#  [ 2.03595563  1.89621477]
#  [ 2.27938746  3.64545759]
#  [ 2.66044914  1.87936313]
#  [ 2.61570308  0.48104921]
#  [ 3.23221596 -2.70488277]
#  [ 3.2053903   0.71076133]
#  [ 3.52608717  0.50030312]
#  [ 3.27565592  0.58018126]
#  [ 2.83260755 -0.14955423]
#  [ 2.84104728  0.00657711]
#  [ 2.94476281  1.29017705]
#  [ 3.06664074  1.45586266]
#  [ 2.7691772   1.12270377]
#  [ 2.92921598  2.20932543]
#  [ 2.92970962  0.27652253]
#  [ 2.96000283 -0.37351814]
#  [ 2.9519791  -0.70200243]
#  [ 3.01793374  0.0643789 ]
#  [ 3.21981251  0.67972281]
#  [ 3.28661392 -0.83479633]
#  [ 3.45841256  0.42303329]
#  [ 3.49793032 -0.53088247]
#  [ 3.33992598 -0.86249855]
#  [ 3.27538672 -0.90824181]
#  [ 3.01119932 -0.03481801]
#  [ 3.08892908 -0.82097265]
#  [ 3.00238072 -0.60599034]
#  [ 2.88343814 -0.82125755]
#  [ 2.62633899 -0.69117669]
#  [ 2.27173225 -0.4105554 ]
#  [ 2.54645523 -1.1493365 ]
#  [ 2.85965575 -1.17205836]
#  [ 3.29400678 -1.87576184]
#  [ 3.46643497 -1.17697387]
#  [ 3.55693515 -1.72941726]
#  [ 3.38955424 -1.23257634]]
# (129, 2)

# %%
plt.figure(figsize =(8, 6))
plt.scatter(data_pca[:, 0], data_pca[:, 1],cmap ='plasma')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
pca.components_
# Out:
# array([[ 0.        ,  0.49622191,  0.49586778,  0.497116  , -0.11480085,
#          0.49682003,  0.0272995 ,  0.        ],
#        [ 0.        ,  0.02631746,  0.05184345,  0.01237118,  0.69478453,
#          0.030788  ,  0.71609577,  0.        ]])
