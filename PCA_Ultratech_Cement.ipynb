# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Ultratech.csv')
df = pd.DataFrame(data)
df.head()
# Out:
#    co_code  nse_opening_price  nse_high_price  nse_low_price  nse_traded_qty  \
# 0   125123             3888.0         3933.95         3862.1          331198
# 1   125123             3911.0         3947.00         3882.0          294329
# 2   125123             3926.0         3960.00         3875.0          257664
# 3   125123             3920.0         3944.70         3904.5          254346
# 4   125123             3940.0         3947.85         3826.5          452430
#
#    nse_avg_rate  nse_delivery_qty  equity_facevalue_on_stkdate
# 0       3895.67            100531                           10
# 1       3914.02            125542                           10
# 2       3904.13             82144                           10
# 3       3928.52             99912                           10
# 4       3859.56            208472                           10

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
scalar.fit(data)
scaled_data = scalar.transform(data)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca.fit(scaled_data)
data_pca = pca.transform(scaled_data)
print(data_pca)
data_pca.shape
# Out:
# [[-2.26917888 -0.35733657]
#  [-2.15566287 -0.30696076]
#  [-2.26740869 -0.60084913]
#  [-2.193972   -0.52431345]
#  [-1.95423207  0.41060086]
#  [-1.90604529  1.15477928]
#  [-2.30950831  0.46118378]
#  [-2.41863758  0.14222362]
#  [-2.54629862 -0.07500177]
#  [-2.56746486  0.19967929]
#  [-2.6413861  -0.17950426]
#  [-2.53138076  0.1385698 ]
#  [-2.53021836 -0.36818369]
#  [-2.39447649 -0.29098129]
#  [-1.59812441  1.16647721]
#  [-1.99328702  0.52074126]
#  [-2.42963994 -0.37133669]
#  [-1.96924605  1.4545928 ]
#  [-2.33811183  0.22944699]
#  [ 0.00832834  4.20591065]
#  [ 0.36842443  2.63133734]
#  [-0.83785952 -0.12626147]
#  [-1.15992538 -0.55438953]
#  [-1.04013144  0.26507108]
#  [-1.10186252  0.93621757]
#  [-1.37619826  0.01057725]
#  [-1.54415454 -0.3610328 ]
#  [-1.69582099 -0.43399053]
#  [-1.47107596  0.25468117]
#  [-1.29546828  0.72164766]
#  [-1.88491152 -0.26832661]
#  [-1.40826443  0.11910176]
#  [-1.21413867  0.61278962]
#  [-1.75309722 -0.56930291]
#  [-0.66250979  1.31624379]
#  [-0.49568856  0.54854767]
#  [-1.09768173 -0.62844808]
#  [-0.74044961  0.11754978]
#  [-0.86861734 -0.46048425]
#  [-0.94551685 -0.35794411]
#  [-0.71132149  0.70185287]
#  [-1.2383474   0.10061519]
#  [-1.51750924 -0.48516178]
#  [-1.23110566  0.98925338]
#  [-1.96262774  0.20530385]
#  [-1.55457967  0.78793199]
#  [-2.0897254  -0.63311286]
#  [-1.98256623  0.18875015]
#  [-1.63411603  1.1477861 ]
#  [-2.12682852  0.56025299]
#  [-2.55143652 -0.18823761]
#  [-2.24428019  0.01168264]
#  [-2.08192057 -0.10892782]
#  [-1.94900371  0.12986582]
#  [-2.16476699 -0.39840344]
#  [-1.84478533  0.03139546]
#  [-1.79660124 -0.11074196]
#  [-1.53463353  0.35728181]
#  [-1.94766307 -0.12282473]
#  [-2.18160163  0.0989678 ]
#  [-2.27602589 -0.25009226]
#  [-2.25862445  0.48499524]
#  [-2.70237803 -0.44776838]
#  [-2.31959321 -0.60304357]
#  [-1.40240886  0.58965473]
#  [-1.48393516 -0.39917013]
#  [-1.18008566  0.02178183]
#  [-1.47276855 -0.5284457 ]
#  [-1.40415225 -0.47063699]
#  [-0.22493805  1.35484069]
#  [-0.06102432  0.70574189]
#  [-0.42551541 -0.75571178]
#  [-0.32783241 -0.26631294]
#  [ 1.52186036  2.9430578 ]
#  [ 0.05463976 -0.25906012]
#  [ 0.05158228 -0.72560965]
#  [ 0.15373648 -0.47340602]
#  [ 0.45616443 -0.66229781]
#  [ 0.98898534  0.27623885]
#  [ 1.9759256   2.65694832]
#  [ 2.32754709  2.46951949]
#  [ 1.17065688  0.28955418]
#  [ 0.69836442 -0.04087321]
#  [ 1.41935552  1.30019209]
#  [ 0.61229448 -0.65385577]
#  [ 0.88963549  0.37399481]
#  [ 0.98891385 -0.27124251]
#  [ 0.48941047 -1.1113427 ]
#  [ 0.74656521 -0.50278071]
#  [ 0.57171406 -0.91350758]
#  [ 0.81738651 -0.67638921]
#  [ 0.6284897  -1.09334529]
#  [ 0.76870589 -1.11785004]
#  [ 2.35325256  1.8012886 ]
#  [ 2.08281772  0.25744835]
#  [ 2.07473607 -0.45556509]
#  [ 1.76880849 -1.46546443]
#  [ 1.43580111 -2.96779711]
#  [ 2.68392614 -0.08739219]
#  [ 2.00385125 -1.44280358]
#  [ 1.99536057 -0.84019249]
#  [ 1.63710387 -1.35897824]
#  [ 2.09597944 -1.03946756]
#  [ 1.86923809 -1.52625884]
#  [ 1.98124224 -1.20369609]
#  [ 1.90480689 -0.83661186]
#  [ 2.85603041  1.53037221]
#  [ 2.24960886 -0.36528408]
#  [ 2.56796464 -0.3539789 ]
#  [ 2.62810976 -0.0172966 ]
#  [ 4.75467286  3.77794572]
#  [ 3.30755973 -0.53542016]
#  [ 4.29024215  1.55955274]
#  [ 5.17326852  2.91844369]
#  [ 3.7466601   1.25064309]
#  [ 3.08856521  0.13839004]
#  [ 3.60979945  0.9427162 ]
#  [ 4.58764797  2.28383785]
#  [ 3.14789432 -1.54147763]
#  [ 3.68607981 -0.35769238]
#  [ 3.05316798 -1.74875761]
#  [ 2.71200385 -1.53423348]
#  [ 2.43016414 -1.48808125]
#  [ 2.41282652 -1.76649122]
#  [ 2.56204072 -1.98001246]
#  [ 2.68816707 -1.94951126]
#  [ 2.81864314 -2.11566067]
#  [ 3.72784564 -0.90417238]
#  [ 3.79778131 -1.86897066]]
# (129, 2)

# %%
plt.figure(figsize =(8, 6))
plt.scatter(data_pca[:, 0], data_pca[:, 1], cmap ='plasma')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
df.to_numpy()
data
# Out:
#      co_code  nse_opening_price  nse_high_price  nse_low_price  \
# 0     125123            3888.00         3933.95        3862.10
# 1     125123            3911.00         3947.00        3882.00
# 2     125123            3926.00         3960.00        3875.00
# 3     125123            3920.00         3944.70        3904.50
# 4     125123            3940.00         3947.85        3826.50
# ..       ...                ...             ...            ...
# 124   125123            5099.00         5124.35        5011.65
# 125   125123            5055.40         5160.00        5055.40
# 126   125123            5160.00         5172.75        5081.60
# 127   125123            5157.05         5400.00        5120.05
# 128   125123            5374.00         5379.00        5261.20
#
#      nse_traded_qty  nse_avg_rate  nse_delivery_qty  \
# 0            331198       3895.67            100531
# 1            294329       3914.02            125542
# 2            257664       3904.13             82144
# 3            254346       3928.52             99912
# 4            452430       3859.56            208472
# ..              ...           ...               ...
# 124          431767       5051.24            122631
# 125          410405       5110.35            140554
# 126          401258       5136.56            125754
# 127         1002535       5255.57            209677
# 128          728164       5303.87            138506
#
#      equity_facevalue_on_stkdate
# 0                             10
# 1                             10
# 2                             10
# 3                             10
# 4                             10
# ..                           ...
# 124                           10
# 125                           10
# 126                           10
# 127                           10
# 128                           10
#
# [129 rows x 8 columns]

# %%
final_data = data_pca.T * data.T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-cef1b51f1951> in <module>
# ----> 1 final_data = data_pca.T * data.T
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#     645         # TODO: why are we passing flex=True instead of flex=not special?
#     646         #  15 tests fail if we pass flex=not special instead
# --> 647         self, other = _align_method_FRAME(self, other, axis, flex=True, level=level)
#     648
#     649         if isinstance(other, ABCDataFrame):
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _align_method_FRAME(left, right, axis, flex, level)
#     488
#     489             else:
# --> 490                 raise ValueError(
#     491                     "Unable to coerce to DataFrame, shape "
#     492                     f"must be {left.shape}: given {right.shape}"
#
# ValueError: Unable to coerce to DataFrame, shape must be (8, 129): given (2, 129)

# %%
pca.components_
# Out:
# array([[ 0.        ,  0.46156204,  0.46726748,  0.4617879 ,  0.2499805 ,
#          0.4654511 ,  0.2761133 ,  0.        ],
#        [-0.        , -0.20328141, -0.15679479, -0.20556192,  0.67719119,
#         -0.1768701 ,  0.63400743, -0.        ]])
